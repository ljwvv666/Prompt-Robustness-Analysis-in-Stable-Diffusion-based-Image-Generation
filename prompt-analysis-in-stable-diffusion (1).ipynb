# %%
# !pip install --upgrade diffusers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 32.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: diffusers
#     Found existing installation: diffusers 0.31.0
#     Uninstalling diffusers-0.31.0:
#       Successfully uninstalled diffusers-0.31.0
# ...

# %%
# Prompt 列表
prompts_Subject = [
    "A dog playing in the snow",
    "A person sitting by the lake, reading a book",
    "A sunset behind the mountains",
    "A bird flying in the sky above a forest",
    "A cat sleeping on a cozy couch",
    "A car driving through a foggy road",
    "A child drawing with crayons on paper",
    "A boat sailing on the calm ocean",
    "A horse running across a field",
    "A woman walking in the rain with an umbrella",
    "A man standing under the starry sky",
    "A deer drinking water at a forest stream",
    "A musician playing a violin on stage",
    "A robot exploring a futuristic city",
    "A chef cooking pasta in a cozy kitchen",
    "A dancer spinning gracefully on stage",
    "A train passing through a snowy landscape",
    "A turtle swimming in clear blue water",
    "A couple watching fireworks on a hilltop",
    "A child blowing bubbles in the garden"
]

prompts_Object = [
    "In the snow, a dog playing",
    "By the lake, a person sitting reading a book",
    "Behind the mountains, a sunset",
    "Above a forest, a bird flying in the sky",
    "On a cozy couch, a cat sleeping",
    "Through a foggy road, a car driving",
    "With crayons on paper, a child drawing",
    "On the calm ocean, a boat sailing",
    "Across a field, a horse running",
    "In the rain with an umbrella, a woman walking",
    "Under the starry sky, a man standing",
    "At a forest stream, a deer drinking water",
    "On stage, a musician playing a violin",
    "In a futuristic city, a robot exploring",
    "In a cozy kitchen, a chef cooking pasta",
    "On stage, a dancer spinning gracefully",
    "Through a snowy landscape, a train passing",
    "In clear blue water, a turtle swimming",
    "On a hilltop, a couple watching fireworks",
    "In the garden, a child blowing bubbles"
]

prompts_positive = [
    "A cozy bedroom with warm lighting",
    "A beautiful garden full of blooming flowers",
    "A clear blue sky over a quiet lake",
    "A clean and modern kitchen",
    "A cheerful child playing in the park",
    "A sunny beach with crystal clear water",
    "A spacious living room with elegant furniture",
    "A calm forest trail with soft sunlight",
    "A delicious plate of fresh pasta",
    "A well-organized workspace with bright lighting",
    "A peaceful countryside at sunset",
    "A stylish woman walking down the street",
    "A lovely picnic scene on a green lawn",
    "A sparkling clean bathroom with white tiles",
    "A neat bookshelf filled with colorful books",
    "A friendly dog wagging its tail",
    "A luxurious hotel room with a sea view",
    "A happy couple walking hand in hand",
    "A vibrant market with fresh produce",
    "A smooth road winding through the hills"
]

prompts_negative = [
    "A bedroom with lighting that's not cold or harsh",
    "A garden full of flowers that aren’t dull or wilted",
    "A sky over a lake without any clouds or haze",
    "A kitchen that isn’t dirty or outdated",
    "A child in the park who doesn't look upset or bored",
    "A beach with water that isn’t murky or dark",
    "A living room that doesn't feel cramped or messy",
    "A forest trail without harsh light or noise",
    "A plate of pasta that doesn’t look unappetizing or old",
    "A workspace that isn’t cluttered or poorly lit",
    "A countryside scene that doesn’t feel chaotic or loud",
    "A woman on the street who doesn’t look unstylish or tired",
    "A picnic scene without any trash or discomfort",
    "A bathroom that’s not dirty or stained",
    "A bookshelf that isn’t messy or poorly arranged",
    "A dog wagging its tail that doesn’t look aggressive or scared",
    "A hotel room that doesn’t feel cheap or cramped",
    "A couple walking who don’t look sad or disconnected",
    "A market that doesn’t look empty or disorganized",
    "A road that isn’t bumpy or full of potholes"
]

prompts_plain = [
    "A dog on the grass",
    "A bird flying in the sky",
    "A boat on the lake",
    "A car on the road",
    "A child holding a toy",
    "A woman reading a book",
    "A fish in the water",
    "A bridge over a river",
    "A man riding a bike",
    "A candle on a table",
    "A star in the night sky",
    "A cup of coffee on a plate",
    "A man writing on a board",
    "A girl walking on the beach",
    "A doctor in a hospital",
    "A boy eating an apple",
    "A man standing by the window",
    "A person looking at a phone",
    "A dog barking at a stranger",
    "A student sitting in a classroom"
]

prompts_technical = [
    "A canine on the lawn",
    "An avian soaring in the atmosphere",
    "A vessel on the freshwater body",
    "An automobile on the asphalt",
    "A juvenile grasping a plaything",
    "A female engaging with literature",
    "An aquatic vertebrate in the fluid medium",
    "A structure spanning a fluvial channel",
    "An adult male operating a bicycle",
    "An illumination source on a surface",
    "A celestial body in the nocturnal firmament",
    "A ceramic mug containing brewed beverage on a saucer",
    "An individual inscribing on a writing surface",
    "A young female traversing the shoreline",
    "A medical professional in a clinical facility",
    "A male minor consuming a pome fruit",
    "An adult male positioned adjacent to a fenestration",
    "An individual observing a handheld device",
    "A domesticated canine vocalizing at an unfamiliar human",
    "A learner seated within an educational environment"
]



prompts_normal = [
    "A tall tree in a green field",
    "A red car driving down a straight road",
    "A small bird flying in a clear sky",
    "A person walking on a quiet beach",
    "A white house on a grassy hill",
    "A black cat sitting on a wooden fence",
    "A blue sky over a calm lake",
    "A young child holding a balloon",
    "A simple wooden chair in a kitchen",
    "A clean desk in a home office",
    "A bright room with large windows",
    "A fast train moving through the countryside",
    "A brown dog lying on a rug",
    "A colorful painting on the wall",
    "A shiny car parked on the street",
    "A warm cup of coffee on a table",
    "A wide bridge over a river",
    "A narrow alley between buildings",
    "A happy couple standing in a garden",
    "A clear night sky with stars"
]


prompts_extreme = [
    "A towering tree in a lush green field",
    "A blazing red car racing down a perfectly straight road",
    "A minuscule bird soaring in a crystal-clear sky",
    "A person strolling on an absolutely silent beach",
    "An immaculately white house on a densely grassy hill",
    "A jet-black cat perched on a weathered wooden fence",
    "A vivid blue sky stretching over a perfectly still lake",
    "A very young child tightly holding a colorful balloon",
    "An elegantly simple wooden chair in a cozy kitchen",
    "A spotless desk in an impeccably tidy home office",
    "An intensely bright room filled with huge windows",
    "An ultra-fast train rushing through the peaceful countryside",
    "A chocolate-brown dog resting calmly on a soft rug",
    "A strikingly colorful painting hanging on the plain wall",
    "A gleaming car perfectly parked on the quiet street",
    "A steaming hot cup of freshly brewed coffee on a table",
    "A tremendously wide bridge stretching across the river",
    "An extremely narrow alleyway between tall buildings",
    "A genuinely happy couple standing in a beautifully kept garden",
    "A flawlessly clear night sky filled with twinkling stars"
]

# %%
#从huggingface上面获取你自己的token
from diffusers import DiffusionPipeline
import os

# 加载模型
# 记得加上use_auth_token=AUTH_TOKEN参数
pipeline0 = DiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5")
pipeline0.to("cuda:0")

pipeline1 = DiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5")
pipeline1.to("cuda:1")
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/4.72k [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/617 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/492M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# scheduler_config.json:   0%|          | 0.00/308 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/806 [00:00<?, ?B/s]
# ...

# %%
def make_dirs():
    folders = [
        "clip_eval/images/subject", "clip_eval/texts/subject",
        "clip_eval/images/object", "clip_eval/texts/object",
        "clip_eval/images/positive", "clip_eval/texts/positive",
        "clip_eval/images/negative", "clip_eval/texts/negative",
        "clip_eval/images/plain", "clip_eval/texts/plain",
        "clip_eval/images/technical", "clip_eval/texts/technical",
        "clip_eval/images/normal", "clip_eval/texts/normal",
        "clip_eval/images/extreme", "clip_eval/texts/extreme",
    ]
    for folder in folders:
        os.makedirs(folder, exist_ok=True)

# %%
def task_gpu0():
    for i, (p_plain, p_stylized) in enumerate(zip(prompts_Subject, prompts_Object)):
        for j in range(3):
            index = f"{i}_{j}"

            img_plain = pipeline0(p_plain).images[0]
            img_plain.save(f"clip_eval/images/subject/{index}.png")
            with open(f"clip_eval/texts/subject/{index}.txt", "w") as f:
                f.write(p_plain)

            img_style = pipeline0(p_stylized).images[0]
            img_style.save(f"clip_eval/images/object/{index}.png")
            with open(f"clip_eval/texts/object/{index}.txt", "w") as f:
                f.write(p_stylized)

    for i, (p_plain, p_stylized) in enumerate(zip(prompts_positive, prompts_negative)):
        for j in range(3):
            index = f"{i}_{j}"

            img_plain = pipeline0(p_plain).images[0]
            img_plain.save(f"clip_eval/images/positive/{index}.png")
            with open(f"clip_eval/texts/positive/{index}.txt", "w") as f:
                f.write(p_plain)

            img_style = pipeline0(p_stylized).images[0]
            img_style.save(f"clip_eval/images/negative/{index}.png")
            with open(f"clip_eval/texts/negative/{index}.txt", "w") as f:
                f.write(p_stylized)

# %%
def task_gpu1():
    for i, (p_plain, p_stylized) in enumerate(zip(prompts_plain, prompts_technical)):
        for j in range(3):
            index = f"{i}_{j}"

            img_plain = pipeline1(p_plain).images[0]
            img_plain.save(f"clip_eval/images/plain/{index}.png")
            with open(f"clip_eval/texts/plain/{index}.txt", "w") as f:
                f.write(p_plain)

            img_style = pipeline1(p_stylized).images[0]
            img_style.save(f"clip_eval/images/technical/{index}.png")
            with open(f"clip_eval/texts/technical/{index}.txt", "w") as f:
                f.write(p_stylized)

    for i, (p_plain, p_stylized) in enumerate(zip(prompts_normal, prompts_extreme)):
        for j in range(3):
            index = f"{i}_{j}"

            img_plain = pipeline1(p_plain).images[0]
            img_plain.save(f"clip_eval/images/normal/{index}.png")
            with open(f"clip_eval/texts/normal/{index}.txt", "w") as f:
                f.write(p_plain)

            img_style = pipeline1(p_stylized).images[0]
            img_style.save(f"clip_eval/images/extreme/{index}.png")
            with open(f"clip_eval/texts/extreme/{index}.txt", "w") as f:
                f.write(p_stylized)

# %%
make_dirs()

# %%
# from threading import Thread

# t0 = Thread(target=task_gpu0)
# t1 = Thread(target=task_gpu1)

# t0.start()
# t1.start()

# t0.join()
# t1.join()

# %%
# !zip -r clip_eval.zip clip_eval

# %%
# import matplotlib.pyplot as plt
# import glob

# image_paths = sorted(glob.glob("clip_eval/images/subject/*.png"))[:8]

# plt.figure(figsize=(15, 3))
# for i, path in enumerate(image_paths):
#     img = Image.open(path)
#     plt.subplot(1, len(image_paths), i + 1)
#     plt.imshow(img)
#     plt.axis("off")
#     plt.title(path.split("/")[-1])
# plt.show()

# %% [markdown]
# ## 第一组：句子结构顺序

# %% [markdown]
# ## 第二组：正面与负面提示的组合

# %% [markdown]
# ## 第三组：大白话 vs 专业术语的使用

# %% [markdown]
# ## 第四组：常规和极端的描述

# %% [markdown]
# # 开始评估

# %%
# !pip install git+https://github.com/openai/CLIP.git
# !pip install clip-score
# Out:
# ...
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-zcqdd8s7
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-zcqdd8s7
#   Resolved https://github.com/openai/CLIP.git to commit dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 1.9 MB/s eta 0:00:00
# ...
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1369489 sha256=02173f7c4a4fd0b97e21c7ae3d46ddea780eab84ff980a098f6371bf3a2e0468
#   Stored in directory: /tmp/pip-ephem-wheel-cache-73tp9ajr/wheels/da/2b/4c/d6691fa9597aac8bb85d2ac13b112deb897d5b50f5ad9a37e4
# Successfully built clip
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for clip-score: filename=clip_score-0.1.1-py3-none-any.whl size=9992 sha256=fd4c71788af6dcfd09d3a9a1d02839e18d37d8564ecd98e4f18521621a3f6d98
# ...

# %% [markdown]
# ## **clip_score的计算--衡量文本和图像之间的一致性**

# %%
import subprocess

# 指定文件路径
log_file_path = "/kaggle/working/clip_score_log.txt"

prompt_types = ['normal', 'extreme', 'plain', 'technical', 'subject', 'object', 'negative', 'positive']
clip_scores = {}

# 打开文件进行写入
with open(log_file_path, 'w') as log_file:
    for prompt_type in prompt_types:
        image_dir = f"/kaggle/input/clip-evaluation/clip_eval/images/{prompt_type}"
        text_dir = f"/kaggle/input/clip-evaluation/clip_eval/texts/{prompt_type}"
        cmd = f"python -m clip_score {image_dir} {text_dir}"
        
        log_file.write(f"正在计算 {prompt_type} 的 CLIP Score...\n")
        print(f"正在计算 {prompt_type} 的 CLIP Score...")

        # 使用 subprocess.Popen 来执行命令并将输出重定向到 log 文件
        process = subprocess.Popen(cmd, shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)

        # 逐行读取 stdout 和 stderr
        stdout, stderr = process.communicate()

        # 将 stdout 输出到文件
        for line in stdout.splitlines():
            log_file.write(line.strip() + "\n")
            print(line.strip())  # 输出每行内容（如果需要）

        # # 将 stderr 输出到文件
        # if stderr:
        #     log_file.write(f"错误信息: {stderr}\n")
        #     print(f"错误信息: {stderr}")

        # 解析并记录 CLIP score
        for line in stdout.splitlines():
            if "CLIP Score" in line:
                value = line.split(":")[-1].strip()
                if value:
                    try:
                        score = float(value)
                        clip_scores[prompt_type] = score
                    except ValueError:
                        log_file.write(f"⚠️ 无法转换为 float 的内容: {value}\n")
                        print(f"⚠️ 无法转换为 float 的内容: {value}")
                    break

    # 最终记录所有 CLIP score 的结果
    log_file.write("\n✅ 所有得分:\n")
    log_file.write(str(clip_scores) + "\n")

print("\n✅ 所有得分:")
print(clip_scores)
# Out:
# 正在计算 normal 的 CLIP Score...
# Loading CLIP model: ViT-B/32
# Calculating CLIP Score:
# CLIP Score:  30.58077621459961
# 正在计算 extreme 的 CLIP Score...
# Loading CLIP model: ViT-B/32
# Calculating CLIP Score:
# CLIP Score:  31.332469940185547
# 正在计算 plain 的 CLIP Score...
# Loading CLIP model: ViT-B/32
# Calculating CLIP Score:
# CLIP Score:  28.764448165893555
# 正在计算 technical 的 CLIP Score...
# Loading CLIP model: ViT-B/32
# Calculating CLIP Score:
# CLIP Score:  28.677194595336914
# 正在计算 subject 的 CLIP Score...
# Loading CLIP model: ViT-B/32
# Calculating CLIP Score:
# CLIP Score:  31.914918899536133
# 正在计算 object 的 CLIP Score...
# Loading CLIP model: ViT-B/32
# Calculating CLIP Score:
# CLIP Score:  31.14444923400879
# 正在计算 negative 的 CLIP Score...
# Loading CLIP model: ViT-B/32
# Calculating CLIP Score:
# CLIP Score:  29.426454544067383
# 正在计算 positive 的 CLIP Score...
# Loading CLIP model: ViT-B/32
# Calculating CLIP Score:
# CLIP Score:  30.474971771240234
#
# ✅ 所有得分:
# ...

# %%
clip_scores
# Out:
# {'normal': 30.58077621459961,
#  'extreme': 31.332469940185547,
#  'plain': 28.764448165893555,
#  'technical': 28.677194595336914,
#  'subject': 31.914918899536133,
#  'object': 31.14444923400879,
#  'negative': 29.426454544067383,
#  'positive': 30.474971771240234}

# %%
import matplotlib.pyplot as plt

# 分组定义
groups = [
    ('normal', 'extreme'),
    ('plain', 'technical'),
    ('subject', 'object'),
    ('negative', 'positive')
]

group_labels = ['Normal vs Extreme', 'Plain vs Technical', 'Subject vs Object', 'Negative vs Positive']

# 准备数据
x = range(len(groups))  # 组索引
width = 0.3  # 柱宽

score1 = [clip_scores[p1] for p1, p2 in groups]
score2 = [clip_scores[p2] for p1, p2 in groups]

# 绘图
fig, ax = plt.subplots(figsize=(8, 5))
bars1 = ax.bar([i - width/2 for i in x], score1, width, label='First')
bars2 = ax.bar([i + width/2 for i in x], score2, width, label='Second')

# 设置标签和标题
ax.set_ylabel('CLIP Score')
ax.set_title('CLIP Score Comparison Across Prompt Types')
ax.set_xticks(x)
ax.set_xticklabels(group_labels, rotation=15)

# 添加数值标签
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.2f}',
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),
                    textcoords="offset points",
                    ha='center', va='bottom')

add_labels(bars1)
add_labels(bars2)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **图像质量**

# %%
import numpy as np
import scipy.misc
import scipy.io
from os.path import dirname
from os.path import join
import scipy
from PIL import Image
import numpy as np
import scipy.ndimage
import numpy as np
import scipy.special
import math

gamma_range = np.arange(0.2, 10, 0.001)
a = scipy.special.gamma(2.0/gamma_range)
a *= a
b = scipy.special.gamma(1.0/gamma_range)
c = scipy.special.gamma(3.0/gamma_range)
prec_gammas = a/(b*c)

def aggd_features(imdata):
    #flatten imdata
    imdata.shape = (len(imdata.flat),)
    imdata2 = imdata*imdata
    left_data = imdata2[imdata<0]
    right_data = imdata2[imdata>=0]
    left_mean_sqrt = 0
    right_mean_sqrt = 0
    if len(left_data) > 0:
        left_mean_sqrt = np.sqrt(np.average(left_data))
    if len(right_data) > 0:
        right_mean_sqrt = np.sqrt(np.average(right_data))

    if right_mean_sqrt != 0:
      gamma_hat = left_mean_sqrt/right_mean_sqrt
    else:
      gamma_hat = np.inf
    #solve r-hat norm

    imdata2_mean = np.mean(imdata2)
    if imdata2_mean != 0:
      r_hat = (np.average(np.abs(imdata))**2) / (np.average(imdata2))
    else:
      r_hat = np.inf
    rhat_norm = r_hat * (((math.pow(gamma_hat, 3) + 1)*(gamma_hat + 1)) / math.pow(math.pow(gamma_hat, 2) + 1, 2))

    #solve alpha by guessing values that minimize ro
    pos = np.argmin((prec_gammas - rhat_norm)**2);
    alpha = gamma_range[pos]

    gam1 = scipy.special.gamma(1.0/alpha)
    gam2 = scipy.special.gamma(2.0/alpha)
    gam3 = scipy.special.gamma(3.0/alpha)

    aggdratio = np.sqrt(gam1) / np.sqrt(gam3)
    bl = aggdratio * left_mean_sqrt
    br = aggdratio * right_mean_sqrt

    #mean parameter
    N = (br - bl)*(gam2 / gam1)#*aggdratio
    return (alpha, N, bl, br, left_mean_sqrt, right_mean_sqrt)

def ggd_features(imdata):
    nr_gam = 1/prec_gammas
    sigma_sq = np.var(imdata)
    E = np.mean(np.abs(imdata))
    rho = sigma_sq/E**2
    pos = np.argmin(np.abs(nr_gam - rho));
    return gamma_range[pos], sigma_sq

def paired_product(new_im):
    shift1 = np.roll(new_im.copy(), 1, axis=1)
    shift2 = np.roll(new_im.copy(), 1, axis=0)
    shift3 = np.roll(np.roll(new_im.copy(), 1, axis=0), 1, axis=1)
    shift4 = np.roll(np.roll(new_im.copy(), 1, axis=0), -1, axis=1)

    H_img = shift1 * new_im
    V_img = shift2 * new_im
    D1_img = shift3 * new_im
    D2_img = shift4 * new_im

    return (H_img, V_img, D1_img, D2_img)


def gen_gauss_window(lw, sigma):
    sd = np.float32(sigma)
    lw = int(lw)
    weights = [0.0] * (2 * lw + 1)
    weights[lw] = 1.0
    sum = 1.0
    sd *= sd
    for ii in range(1, lw + 1):
        tmp = np.exp(-0.5 * np.float32(ii * ii) / sd)
        weights[lw + ii] = tmp
        weights[lw - ii] = tmp
        sum += 2.0 * tmp
    for ii in range(2 * lw + 1):
        weights[ii] /= sum
    return weights

def compute_image_mscn_transform(image, C=1, avg_window=None, extend_mode='constant'):
    if avg_window is None:
      avg_window = gen_gauss_window(3, 7.0/6.0)
    assert len(np.shape(image)) == 2
    h, w = np.shape(image)
    mu_image = np.zeros((h, w), dtype=np.float32)
    var_image = np.zeros((h, w), dtype=np.float32)
    image = np.array(image).astype('float32')
    scipy.ndimage.correlate1d(image, avg_window, 0, mu_image, mode=extend_mode)
    scipy.ndimage.correlate1d(mu_image, avg_window, 1, mu_image, mode=extend_mode)
    scipy.ndimage.correlate1d(image**2, avg_window, 0, var_image, mode=extend_mode)
    scipy.ndimage.correlate1d(var_image, avg_window, 1, var_image, mode=extend_mode)
    var_image = np.sqrt(np.abs(var_image - mu_image**2))
    return (image - mu_image)/(var_image + C), var_image, mu_image


def _niqe_extract_subband_feats(mscncoefs):
    # alpha_m,  = extract_ggd_features(mscncoefs)
    alpha_m, N, bl, br, lsq, rsq = aggd_features(mscncoefs.copy())
    pps1, pps2, pps3, pps4 = paired_product(mscncoefs)
    alpha1, N1, bl1, br1, lsq1, rsq1 = aggd_features(pps1)
    alpha2, N2, bl2, br2, lsq2, rsq2 = aggd_features(pps2)
    alpha3, N3, bl3, br3, lsq3, rsq3 = aggd_features(pps3)
    alpha4, N4, bl4, br4, lsq4, rsq4 = aggd_features(pps4)
    return np.array([alpha_m, (bl+br)/2.0,
            alpha1, N1, bl1, br1,  # (V)
            alpha2, N2, bl2, br2,  # (H)
            alpha3, N3, bl3, bl3,  # (D1)
            alpha4, N4, bl4, bl4,  # (D2)
    ])

def get_patches_train_features(img, patch_size, stride=8):
    return _get_patches_generic(img, patch_size, 1, stride)

def get_patches_test_features(img, patch_size, stride=8):
    return _get_patches_generic(img, patch_size, 0, stride)

def extract_on_patches(img, patch_size):
    h, w = img.shape
    patch_size = int(patch_size)
    patches = []
    for j in range(0, h-patch_size+1, patch_size):
        for i in range(0, w-patch_size+1, patch_size):
            patch = img[j:j+patch_size, i:i+patch_size]
            patches.append(patch)

    patches = np.array(patches)
    
    patch_features = []
    for p in patches:
        patch_features.append(_niqe_extract_subband_feats(p))
    patch_features = np.array(patch_features)

    return patch_features

def _get_patches_generic(img, patch_size, is_train, stride):
    h, w = np.shape(img)
    if h < patch_size or w < patch_size:
        print("Input image is too small")
        exit(0)

    # ensure that the patch divides evenly into img
    hoffset = (h % patch_size)
    woffset = (w % patch_size)

    if hoffset > 0: 
        img = img[:-hoffset, :]
    if woffset > 0:
        img = img[:, :-woffset]


    # 你的原始代码
    img = img.astype(np.float32)
    
    # 将 NumPy 数组转换为 PIL 图像对象
    img_pil = Image.fromarray(img)
    
    # 使用 Image.resize 进行图像缩放
    img_resized = img_pil.resize((int(img_pil.width * 0.5), int(img_pil.height * 0.5)), Image.BICUBIC)
    
    # 将调整大小后的图像保存到 img2 变量
    img2 = np.array(img_resized)  # 如果需要将图像转换回 NumPy 数组

    mscn1, var, mu = compute_image_mscn_transform(img)
    mscn1 = mscn1.astype(np.float32)

    mscn2, _, _ = compute_image_mscn_transform(img2)
    mscn2 = mscn2.astype(np.float32)


    feats_lvl1 = extract_on_patches(mscn1, patch_size)
    feats_lvl2 = extract_on_patches(mscn2, patch_size/2)

    feats = np.hstack((feats_lvl1, feats_lvl2))# feats_lvl3))

    return feats

def niqe(inputImgData):

    patch_size = 96
    module_path = dirname('/kaggle/input/niqeee/')

    # TODO: memoize
    params = scipy.io.loadmat(join(module_path,'niqe_image_params.mat'))
    pop_mu = np.ravel(params["pop_mu"])
    pop_cov = params["pop_cov"]


    M, N = inputImgData.shape

    # assert C == 1, "niqe called with videos containing %d channels. Please supply only the luminance channel" % (C,)
    assert M > (patch_size*2+1), "niqe called with small frame size, requires > 192x192 resolution video using current training parameters"
    assert N > (patch_size*2+1), "niqe called with small frame size, requires > 192x192 resolution video using current training parameters"


    feats = get_patches_test_features(inputImgData, patch_size)
    sample_mu = np.mean(feats, axis=0)
    sample_cov = np.cov(feats.T)

    X = sample_mu - pop_mu
    covmat = ((pop_cov+sample_cov)/2.0)
    pinvmat = scipy.linalg.pinv(covmat)
    niqe_score = np.sqrt(np.dot(np.dot(X, pinvmat), X))

    return niqe_score


# if __name__ == "__main__":
    
#     # ref = np.array(Image.open('./test_imgs/bikes.bmp').convert('LA'))[:,:,0] # ref
#     dis = np.array(Image.open('/kaggle/input/clipevaluation/images/extreme/0_0.png').convert('LA'))[:,:,0] # dis

#     # print('NIQE of ref bikes image is: %0.3f'% niqe(ref))
#     print('NIQE of dis bikes image is: %0.3f'% niqe(dis))

# %%
import os
import numpy as np
from PIL import Image

# 计算NIQE分数的函数（假设已经有 `niqe` 函数实现）
def calculate_niqe_for_directory(directory_path):
    # 创建一个空字典存储不同类别的NIQE分数
    niqe_scores = {}

    # 遍历目录下的所有子目录
    for category in os.listdir(directory_path):
        category_path = os.path.join(directory_path, category)
        
        # 检查是否为文件夹
        if os.path.isdir(category_path):
            # 获取该类别下所有图像文件
            category_images = [f for f in os.listdir(category_path) if f.lower().endswith(('png', 'jpg', 'jpeg'))]
            
            # 存储该类别所有图像的NIQE分数
            niqe_sum = 0
            for image_file in category_images:
                image_path = os.path.join(category_path, image_file)
                
                # 打开并处理图像
                dis = np.array(Image.open(image_path).convert('LA'))[:,:,0]
                
                # 计算该图像的NIQE分数
                niqe_sum += niqe(dis)
            
            # 计算该类别的平均NIQE分数
            niqe_scores[category] = niqe_sum / len(category_images) if category_images else 0

    return niqe_scores

# 示例调用
directory_path = "/kaggle/input/clip-evaluation/clip_eval/images"  # 图像文件夹路径
niqe_results = calculate_niqe_for_directory(directory_path)

print(niqe_results)
# Out:
# {'object': 12.696810791310337, 'plain': 12.023352590682, 'subject': 12.022546459106747, 'negative': 13.37638711829525, 'normal': 13.38488389977068, 'technical': 12.584337010381235, 'extreme': 13.119683157900958, 'positive': 13.288750683505206}

# %%
import matplotlib.pyplot as plt

# 分组定义
groups = [
    ('normal', 'extreme'),
    ('plain', 'technical'),
    ('subject', 'object'),
    ('negative', 'positive')
]

group_labels = ['Normal vs Extreme', 'Plain vs Technical', 'Subject vs Object', 'Negative vs Positive']

# 准备数据
x = range(len(groups))  # 组索引
width = 0.3  # 柱宽

score1 = [niqe_results[p1] for p1, p2 in groups]
score2 = [niqe_results[p2] for p1, p2 in groups]

# 绘图
fig, ax = plt.subplots(figsize=(8, 5))
bars1 = ax.bar([i - width/2 for i in x], score1, width, label='First')
bars2 = ax.bar([i + width/2 for i in x], score2, width, label='Second')

# 设置标签和标题
ax.set_ylabel('NIQE Score')
ax.set_title('NIQE Score Comparison Across Prompt Types')
ax.set_xticks(x)
ax.set_xticklabels(group_labels, rotation=15)

# 添加数值标签
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.2f}',
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),
                    textcoords="offset points",
                    ha='center', va='bottom')

add_labels(bars1)
add_labels(bars2)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **视觉聚类可视化**

# %%
# !pip install open_clip_torch
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 23.6 MB/s eta 0:00:00
# ...

# %%
import os
import torch
import matplotlib.pyplot as plt
from PIL import Image
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import open_clip
from torchvision import transforms

# %%
# 设置你的图像路径
IMAGE_DIR = "/kaggle/input/clip-evaluation/clip_eval/images"
CATEGORIES = os.listdir(IMAGE_DIR)

# 加载 CLIP 模型
model, _, preprocess = open_clip.create_model_and_transforms('ViT-B-32', pretrained='laion2b_s34b_b79k')
tokenizer = open_clip.get_tokenizer('ViT-B-32')
model.eval()

# 图像预处理
image_preprocess = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.4815, 0.4578, 0.4082], [0.2686, 0.2613, 0.2758])
])

# 提取图像特征
features = []
labels = []

for category in CATEGORIES:
    cat_path = os.path.join(IMAGE_DIR, category)
    for filename in os.listdir(cat_path):
        if not filename.endswith(".png"): continue
        img_path = os.path.join(cat_path, filename)
        image = Image.open(img_path).convert("RGB")
        img_tensor = image_preprocess(image).unsqueeze(0)
        with torch.no_grad():
            image_features = model.encode_image(img_tensor)
        features.append(image_features.squeeze().cpu().numpy())
        labels.append(category)

print(f"提取 {len(features)} 张图像的特征")
# Out:
# open_clip_model.safetensors:   0%|          | 0.00/605M [00:00<?, ?B/s]
# 提取 480 张图像的特征

# %%
features = torch.tensor(features)
# Out:
# <ipython-input-21-656970351ced>:1: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:278.)
#   features = torch.tensor(features)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA

# 你的四组对比实验标签和标题
experiments = [
    (['normal', 'extreme'], 'normal vs extreme'),
    (['plain', 'technical'], 'plain vs technical'),
    (['subject', 'object'], 'subject vs object'),
    (['negative', 'positive'], 'negative vs positive'),
]

fig, axes = plt.subplots(2, 2, figsize=(8, 6))
axes = axes.flatten()

for idx, (selected_labels, title) in enumerate(experiments):
    # 筛选当前这组的特征和标签
    mask = [label in selected_labels for label in labels]
    filtered_features = features[mask]
    filtered_labels = [label for label in labels if label in selected_labels]

    # PCA（也可以改成 t-SNE 或 UMAP）
    pca = PCA(n_components=2, random_state=42)
    pca_result = pca.fit_transform(filtered_features)

    # 子图画图
    ax = axes[idx]
    sns.scatterplot(
        x=pca_result[:, 0], y=pca_result[:, 1],
        hue=filtered_labels, palette='Set2', s=60, ax=ax
    )
    ax.set_title(f'PCA of {title}')
    ax.legend(loc='best')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA

# 你的四组对比实验标签和标题
experiments = [
    (['normal', 'extreme'], 'normal vs extreme'),
    (['plain', 'technical'], 'plain vs technical'),
    (['subject', 'object'], 'subject vs object'),
    (['negative', 'positive'], 'negative vs positive'),
]

fig, axes = plt.subplots(2, 2, figsize=(8, 6))
axes = axes.flatten()

for idx, (selected_labels, title) in enumerate(experiments):
    # 筛选当前这组的特征和标签
    mask = [label in selected_labels for label in labels]
    filtered_features = features[mask]
    filtered_labels = [label for label in labels if label in selected_labels]

    # PCA（也可以改成 t-SNE 或 UMAP）
    tsne = TSNE(n_components=2, random_state=42)
    pca_result = tsne.fit_transform(filtered_features)

    # 子图画图
    ax = axes[idx]
    sns.scatterplot(
        x=pca_result[:, 0], y=pca_result[:, 1],
        hue=filtered_labels, palette='Set2', s=60, ax=ax
    )
    ax.set_title(f'T-SNE of {title}')
    ax.legend(loc='best')

plt.tight_layout()
plt.show()

# %%
# 降维
features = torch.tensor(features)
reducer = TSNE(n_components=2, perplexity=30, init='pca', learning_rate=200)
features_2d = reducer.fit_transform(features)

# 可视化
plt.figure(figsize=(6, 5))
colors = plt.cm.tab10.colors
label_to_color = {label: colors[i % 10] for i, label in enumerate(set(labels))}

for point, label in zip(features_2d, labels):
    plt.scatter(point[0], point[1], color=label_to_color[label], label=label, alpha=0.6)

# 添加图例（不重复）
handles = []
added = set()
for label in labels:
    if label not in added:
        handles.append(plt.Line2D([], [], marker='o', color=label_to_color[label], linestyle='None', label=label))
        added.add(label)
plt.legend(handles=handles, loc='best')
plt.title("t-SNE Visualization of Image Embeddings by Prompt Type")
plt.tight_layout()
plt.savefig("tsne_clip_visualization.png", dpi=300)
plt.show()
# Out:
# <ipython-input-24-7ff6ca5d2f47>:2: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   features = torch.tensor(features)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
features_2d = pca.fit_transform(features)

# 可视化
plt.figure(figsize=(6, 5))
colors = plt.cm.tab10.colors
label_to_color = {label: colors[i % 10] for i, label in enumerate(set(labels))}

for point, label in zip(features_2d, labels):
    plt.scatter(point[0], point[1], color=label_to_color[label], label=label, alpha=0.6)

# 添加图例（不重复）
handles = []
added = set()
for label in labels:
    if label not in added:
        handles.append(plt.Line2D([], [], marker='o', color=label_to_color[label], linestyle='None', label=label))
        added.add(label)
plt.legend(handles=handles, loc='best')
plt.title("t-SNE Visualization of Image Embeddings by Prompt Type")
plt.tight_layout()
plt.savefig("tsne_clip_visualization.png", dpi=300)
plt.show()
